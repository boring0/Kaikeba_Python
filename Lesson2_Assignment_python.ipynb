# %% [markdown]
# ![](https://img.kaikeba.com/web/kkb_index/img_index_logo.png)

# %% [markdown]
# # 基础课第一部分（python）第二次作业
#
# 同学们～大家好！又到了做作业的时间了！上次的作业有 print使用 和 安装Python Pycharm Anaconda 的教程，请确认安装软件好了～
# 本次作业有三个题目：
# - 1. 实现一周的记账功能
# - 2. 实现ATM机功能
# - 3. 词汇表生成及统计
#
# ## 1. 实现一周的记账功能
#
# 首先记录输入的7天的收入，然后记录输入的7天的支出。
# 然后打印出以下内容：
# - 7天的收入(list)
# - 7天的支出(list)
# - 每天的结余(dict)
# - 最终的结余

# %%
Day_Num_All= []
for Sum_New in range(1,8):
    print("请输入第%s天收入:"% Sum_New)
    Day_Num = int(input())
    Day_Num_All=Day_Num_All+[Day_Num]
Day_Num_All_Less=int()
for Less_New in range(1,8):
    print("请输入第%s天支出:" % Less_New)
    Day_Num_Less = int(input())
    Less_New_De=Less_New-1
    Day_Num_De=Day_Num_All[Less_New_De]-Day_Num_Less
    Day_Num_All_Less=Day_Num_All_Less+Day_Num_De
    print("第%s天结余:%s"% (Less_New,Day_Num_De))
print("当前总结余:%s"% Day_Num_All_Less)
# Out:
# 请输入第1天收入:
# 5
# 请输入第2天收入:
# 5
# 请输入第3天收入:
# 5
# 请输入第4天收入:
# 5
# 请输入第5天收入:
# 5
# 请输入第6天收入:
# 5
# 请输入第7天收入:
# 5
# 请输入第1天支出:
# 1
# 第1天结余:4
# 请输入第2天支出:
# 1
# 第2天结余:4
# 请输入第3天支出:
# 1
# 第3天结余:4
# 请输入第4天支出:
# 1
# 第4天结余:4
# 请输入第5天支出:
# 1
# 第5天结余:4
# 请输入第6天支出:
# 1
# 第6天结余:4
# 请输入第7天支出:
# 1
# 第7天结余:4
# 当前总结余:28

# %% [markdown]
# ## 2. 实现ATM机器
# - 查询余额
# - 存款
# - 取款
# - 退出

# %%
import random
User_Sum_Num=random.randint(1300,2620)
Quit_Num=0
while Quit_Num == 0:
    print("请选择您要的功能:\n\t1、查询余额\n\t2、存款\n\t3、取款\n\t4、退出")
    Mess_All= int(input())
    if Mess_All == 1:
        print("您当前余额为:%s"%User_Sum_Num)
    elif Mess_All == 2:
        print("请输入需存款金额:")
        User_Sum_Num_New=int(input())
        User_Sum_Num = User_Sum_Num + User_Sum_Num_New
    elif Mess_All == 3:
        print("请输入需取款金额:")
        User_Sum_Num_De=int(input())
        User_Sum_Num = User_Sum_Num - User_Sum_Num_De
    elif Mess_All == 4:
        Quit_Num=1
# Out:
# 请选择您要的功能:
# 	1、查询余额
# 	2、存款
# 	3、取款
# 	4、退出
# 4

# %% [markdown]
# ## 3. 词汇表生成及统计
#
# 下面是一段[文本](http://baijiahao.baidu.com/s?id=1646569900805781240&wfr=spider&for=pc)：
#
# > 2019年十月一日上午，庆祝中华人民共和国成立70周年阅兵式在首都北京盛大举行，59个阅兵方阵，580台受阅装备，1.5万人的参阅队伍接受了全国人民的检阅。阅兵装备方队展示的武器装备皆为国产现役主战装备，40%为首次展示。其中近些年来广受全球关注的东风41洲际弹道导弹，巨浪二潜射弹道导弹，东风17高超音速武器系统终于揭幕亮剑，以"不怒自威"的形象向世界展示中国捍卫和平的意志与力量。相较于其他首度公开亮相的武器装备，这三款武器多年来传闻不断，备受关注，并因其"大国基石"的地位而被公众赋予特殊的期待，这三款武器装备实力究竟如何，又各自承担着怎样的历史"使命"呢？本报特约相关领域军事专家，为大家详细解读这三款彰显国威，震撼世界的国之重器。
#
# 经过分词后得到以下单词，通过空格分隔。
#
# ```python
# text = '2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。'
# ```
#
# 将文本生成词汇表(单词list)，单词对应ID的dict，以及ID对应单词的dict。
# 将你的程序变成一个盒子，
#
# 输入就是上面一段文本，
#
# 盒子内部：首先将文本转换成单词列表，再得到统计的单词表(去重)，然后得到单词ID相互对应的字典。
#
# 输出：词汇表，word2id, id2word
# 效果如下：
#
# ```python
# vocab = ['大家', '中国', '捍卫', ...}
# word2id = {'大家': 0, '中国': 1, '捍卫': 2, ...}
# id2word = {0: '大家', 1: '中国', 2: '捍卫', ...}
# ```

# %%
# coding=gbk
#text = '2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。'
text = input()
Name_All = []
Name_De=''
Name_Sum=0
Name_All_Word2Id = dict()
Name_All_Id2Word = dict()
for name in text:
    if name == ' ':
        Name_All=Name_All+[Name_De]
        Name_De=''
    else:
        Name_De=Name_De+name
Name_All_read = set()
for Name_All_De in Name_All:
    Name_All_read.add(Name_All_De)
for Name_All_Word in Name_All_read:
    Name_All_Word2Id[Name_All_Word]=Name_Sum
    Name_All_Id2Word[Name_Sum]=Name_All_Word
    Name_Sum=Name_Sum+1
print(Name_All_read)
print(Name_All_Word2Id)
print(Name_All_Id2Word)
# Out:
# 2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。
# {'与', '相关', '十月', '又', '40%', '的', '近些年来', '捍卫', '阅', '期待', '。', '了', '41', '怎样', '59', '并', '向', '全球', '洲际', '中国', '公众', '盛大举行', '彰显', '个', '相较', '历史', '全国', '本报', '大家', '传闻', '终于', '年', '三款', '580', '使命', '70', '周年', '武器', '着', '详细', '"', '特约', '国威', '成立', '公开', '庆祝', '上午', '备受', '二潜射', '而', '国', '皆', '亮剑', '装备', '接受', '方队', '17', '人民', '展示', '不断', '不怒', '来', '军事', '阅兵', '在', '首次', '重器', '关注', '于', '其他', '以', '队伍', '自威', '大国', '系统', '地位', '形象', '其中', '为', '检阅', '首度', '亮相', '究竟', '解读', '台受', '这', '现役', '弹道导弹', '多年', '和平', '专家', '之', '首都北京', '如何', '，', '其', '呢', '主战', '方阵', '1.5', '意志', '震撼', '力量', '世界', '基石', '国产', '武器装备', '领域', '因', '阅兵式', '广受', '承担', '一日', '实力', '揭幕', '2019', '高超音速', '赋予', '参阅', '各自', '特殊', '巨浪', '万人', '被', '东风', '中华人民共和国', '？'}
# {'与': 0, '相关': 1, '十月': 2, '又': 3, '40%': 4, '的': 5, '近些年来': 6, '捍卫': 7, '阅': 8, '期待': 9, '。': 10, '了': 11, '41': 12, '怎样': 13, '59': 14, '并': 15, '向': 16, '全球': 17, '洲际': 18, '中国': 19, '公众': 20, '盛大举行': 21, '彰显': 22, '个': 23, '相较': 24, '历史': 25, '全国': 26, '本报': 27, '大家': 28, '传闻': 29, '终于': 30, '年': 31, '三款': 32, '580': 33, '使命': 34, '70': 35, '周年': 36, '武器': 37, '着': 38, '详细': 39, '"': 40, '特约': 41, '国威': 42, '成立': 43, '公开': 44, '庆祝': 45, '上午': 46, '备受': 47, '二潜射': 48, '而': 49, '国': 50, '皆': 51, '亮剑': 52, '装备': 53, '接受': 54, '方队': 55, '17': 56, '人民': 57, '展示': 58, '不断': 59, '不怒': 60, '来': 61, '军事': 62, '阅兵': 63, '在': 64, '首次': 65, '重器': 66, '关注': 67, '于': 68, '其他': 69, '以': 70, '队伍': 71, '自威': 72, '大国': 73, '系统': 74, '地位': 75, '形象': 76, '其中': 77, '为': 78, '检阅': 79, '首度': 80, '亮相': 81, '究竟': 82, '解读': 83, '台受': 84, '这': 85, '现役': 86, '弹道导弹': 87, '多年': 88, '和平': 89, '专家': 90, '之': 91, '首都北京': 92, '如何': 93, '，': 94, '其': 95, '呢': 96, '主战': 97, '方阵': 98, '1.5': 99, '意志': 100, '震撼': 101, '力量': 102, '世界': 103, '基石': 104, '国产': 105, '武器装备': 106, '领域': 107, '因': 108, '阅兵式': 109, '广受': 110, '承担': 111, '一日': 112, '实力': 113, '揭幕': 114, '2019': 115, '高超音速': 116, '赋予': 117, '参阅': 118, '各自': 119, '特殊': 120, '巨浪': 121, '万人': 122, '被': 123, '东风': 124, '中华人民共和国': 125, '？': 126}
# {0: '与', 1: '相关', 2: '十月', 3: '又', 4: '40%', 5: '的', 6: '近些年来', 7: '捍卫', 8: '阅', 9: '期待', 10: '。', 11: '了', 12: '41', 13: '怎样', 14: '59', 15: '并', 16: '向', 17: '全球', 18: '洲际', 19: '中国', 20: '公众', 21: '盛大举行', 22: '彰显', 23: '个', 24: '相较', 25: '历史', 26: '全国', 27: '本报', 28: '大家', 29: '传闻', 30: '终于', 31: '年', 32: '三款', 33: '580', 34: '使命', 35: '70', 36: '周年', 37: '武器', 38: '着', 39: '详细', 40: '"', 41: '特约', 42: '国威', 43: '成立', 44: '公开', 45: '庆祝', 46: '上午', 47: '备受', 48: '二潜射', 49: '而', 50: '国', 51: '皆', 52: '亮剑', 53: '装备', 54: '接受', 55: '方队', 56: '17', 57: '人民', 58: '展示', 59: '不断', 60: '不怒', 61: '来', 62: '军事', 63: '阅兵', 64: '在', 65: '首次', 66: '重器', 67: '关注', 68: '于', 69: '其他', 70: '以', 71: '队伍', 72: '自威', 73: '大国', 74: '系统', 75: '地位', 76: '形象', 77: '其中', 78: '为', 79: '检阅', 80: '首度', 81: '亮相', 82: '究竟', 83: '解读', 84: '台受', 85: '这', 86: '现役', 87: '弹道导弹', 88: '多年', 89: '和平', 90: '专家', 91: '之', 92: '首都北京', 93: '如何', 94: '，', 95: '其', 96: '呢', 97: '主战', 98: '方阵', 99: '1.5', 100: '意志', 101: '震撼', 102: '力量', 103: '世界', 104: '基石', 105: '国产', 106: '武器装备', 107: '领域', 108: '因', 109: '阅兵式', 110: '广受', 111: '承担', 112: '一日', 113: '实力', 114: '揭幕', 115: '2019', 116: '高超音速', 117: '赋予', 118: '参阅', 119: '各自', 120: '特殊', 121: '巨浪', 122: '万人', 123: '被', 124: '东风', 125: '中华人民共和国', 126: '？'}

# %% [markdown]
# 本次的作业就到这里了！祝大家学习进步！
# ![image alt <](http://5b0988e595225.cdn.sohucs.com/images/20190420/1d1070881fd540db817b2a3bdd967f37.gif)
